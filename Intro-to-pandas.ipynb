# %% [markdown]
# <h1> Python for Data Analysis - Pandas - Introduction</h1>

# %%
# !pip install pandas
# Out:
# ...
# tensorflow 1.3.0 requires tensorflow-tensorboard<0.2.0,>=0.1.0, which is not installed.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h2> Pandas Series</h2>

# %% [markdown]
# <h3> A Panda Series can hold just about any data type; arrays, strings, numbers, dictionaries, lists, data functions etc.</h3>

# %%
labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
arr
# Out:
# array([10, 20, 30])

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data = my_data)                   # Create a Series with data = my_data
                                            # No index was specified in the Series
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = my_data, index = labels)   # Creating a Series with list data = my_data
                                            # Specifying index as 'labels'
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_data,labels)                   # Creating the Series with my_data and labels
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)                              # Pass in numpy array (arr) into Series
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)                      # Pass in numpy array (arr) and labels into Series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)                               # Pass dictionary (d) in the Series
                                           # Note: The output will list keys as indexes and values as data
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data=[sum,print,len])              # Series can hold data functions too
                                             # Note: Numpy can't do this
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# <h2> Grabbing Information from a Pandas Series</h2>

# %%
ser1 = pd.Series([1,2,3,4],['USA', 'Germany', 'USSR', 'Japan'])       # Building a test Series, called ser1 with data [1,2,3,4] and indexes ['USA', 'Germany', 'USSR', 'Japan']

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],['USA','Germany','Italy','Japan'])       # Building a test Series, called ser2 with data [1,2,5,4] and indexes ['USA','Germany','Italy','Japan']

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1['USA']                                 # Grabbing data by referencing the index.
                                            # In this case, the index for string 'USA' references value 1
# Out:
# 1

# %%
ser2['Japan']                               # Grabbing data for index Japan
# Out:
# 4

# %%
ser3 = pd.Series(labels)

# %%
ser3                                        # Note dtype is object, which refers to the values as strings
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser3[1]
# Out:
# 'b'

# %%
ser3[2]
# Out:
# 'c'

# %%
ser3[0]
# Out:
# 'a'

# %% [markdown]
# <h4> Basic Operations</h4>

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1 + ser2                     # Adding Series
                                # If there are matches in both series, a value will be returned
                                # If there IS NOT a match in both series, then NaN is returned
                                # For example, Italy and USSR are not in both Series, so Nan is returned for those values
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64
