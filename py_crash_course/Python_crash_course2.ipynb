# %% [markdown]
# <h3>Dictionaries</h3>

# %%
d = {'key1': 'value', 'key2':123} #dictionary has key:value pairs

# %%
d
# Out:
# {'key1': 'value', 'key2': 123}

# %%
d['key1']
# Out:
# 'value'

# %%
d['key2']
# Out:
# 123

# %%
d1 = {'k1':[1,2,3]} # A list inside of a dictionary

# %%
d1
# Out:
# {'k1': [1, 2, 3]}

# %%
d1['k1'] # Only calling the key
# Out:
# [1, 2, 3]

# %%
d1['k1'][0] # index value
# Out:
# 1

# %%
d1['k1'][1] # index value
# Out:
# 2

# %%
d1['k1'][2] # index value
# Out:
# 3

# %%
d2 = {'k1':{'innerkey': [1,2,3]}} # Nested dictionary in a dictionary

# %%
d2['k1']['innerkey'][1] # Get the 1st index value from the nested dictionary, starting with the outer dictionary
# Out:
# 2

# %% [markdown]
# <h3>Boolean</h3>

# %%
# Used most in comparative sets

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# <h3>Tuples</h3>

# %%
# Tuples are immutable = Can't change the values inside of them.

# %%
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 'FRESH' # Tuples are immutable = Can't change the values inside of them.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-9ea27081c9d8> in <module>()
# ----> 1 t[0] = 'FRESH'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# <h3>Sets</h3>

# %%
# A collection of **unique** elements

# %%
{1,2,3}
# Out:
# {1, 2, 3}

# %%
{1,1,1,1,2,2,2,3,3,3}
# Out:
# {1, 2, 3}

# %%
set([1,1,1,1,2,2,2,3,3,3])
# Out:
# {1, 2, 3}

# %%
s = {1,2,3}

# %%
s.add(5) # Add 5 to the set (Sets are mutable)

# %%
s
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# <h3>Comparison Operators</h3>

# %%
# < > == <= >=

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 2
# Out:
# False

# %%
1 <= 2
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
1 != 3
# Out:
# True

# %%
'hi' == 'bye'
# Out:
# False

# %%
'hi' != 'bye'
# Out:
# True

# %% [markdown]
# <h3> AND/OR </h3>

# %%
(1 < 2) and (2 < 3)  # Both have to be true, to return 'True'
# Out:
# True

# %%
(1 < 2) and (2 > 3)
# Out:
# False

# %%
(1 < 2) or (2 > 3)  # One can be true and the other can be false
# Out:
# True

# %% [markdown]
# <h3>IF/ELIF/ELSE: - Conditional Code Blocks</h3>

# %%
if 1 < 2:
    print('yep!')
# Out:
# yep!

# %%
if 1 == 2:
    print('first')
else:
    print('last')
# Out:
# last

# %%
if 1 == 2:
    print('first')
elif 4 == 4:
    print('second')
elif 3 == 3:
    print('middle')
else:
    print('last')
# Out:
# second
