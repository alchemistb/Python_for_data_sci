# %% [markdown]
# <H1>Python Refresher</h1>

# %%
1+1
# Out:
# 2

# %%
1.0
# Out:
# 1.0

# %%
1*3
# Out:
# 3

# %%
1/2
# Out:
# 0.5

# %%
2 ** 4 #2 to the power of 4
# Out:
# 16

# %%
2 + 3 * 5 + 5
# Out:
# 22

# %%
(2+3)* (5+5)
# Out:
# 50

# %%
4 % 2 # remainder
# Out:
# 0

# %%
5%2
# Out:
# 1

# %% [markdown]
# <h2> variable assigntments</h2>

# %%
var = 2

# %%
var
# Out:
# 2

# %%
x = 2
y = 3
x + y
# Out:
# 5

# %%
x = x + x

# %%
x
# Out:
# 4

# %% [markdown]
# <h2>Strings</h2>

# %%
'Single quote'
# Out:
# 'Single quote'

# %%
"This is a string"
# Out:
# 'This is a string'

# %%
"I can't go"
# Out:
# "I can't go"

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 12
name = 'Sam'

# %%
'My Number is {} and my name is {}'.format(num,name) # Using {} and format
# Out:
# 'My Number is 12 and my name is Sam'

# %%
print('My Number is {} and my name is {}'.format(num,name))
# Out:
# My Number is 12 and my name is Sam

# %%
print('My Number is {one} and my name is {two}'.format(one=num,two=name)) # Passing variables in {} and assigning variables format
# Out:
# My Number is 12 and my name is Sam

# %%
print('My Number is {one} and my name is {two}, more {one}'.format(one=num,two=name))
# Out:
# My Number is 12 and my name is Sam, more 12

# %% [markdown]
# <h3>String Index</h3>

# %%
s = 'elephant'

# %%
s[0]
# Out:
# 'e'

# %%
s[4]
# Out:
# 'h'

# %% [markdown]
# <h3>Index Slicing</h3>

# %%
s[:2] # Get the first two values only
# Out:
# 'el'

# %%
s[2:] # Skip the first two values, and get all others
# Out:
# 'ephant'

# %%
s[-1] # Get only the very last value
# Out:
# 't'

# %%
s[0] # Get the first value
# Out:
# 'e'

# %%
s[0:3] # Get the first three values only
# Out:
# 'ele'

# %%
s[0:2] # Get the first two values only
# Out:
# 'el'

# %%
s[0: -1] # Get all but the last value only
# Out:
# 'elephan'

# %% [markdown]
# <h3>List</h3>

# %%
# List are mutable = Can change the values inside of them

# %%
['a', 'b','c']
# Out:
# ['a', 'b', 'c']

# %%
my_list = ['a', 'b','c']

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list.append('d') # append to list

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[3]
# Out:
# 'd'

# %%
my_list[1:3]
# Out:
# ['b', 'c']

# %%
my_list[0] = 'NEW' # (replace)Assign new variable to an index

# %%
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
nest = [[1,2],[3,4]] # Nested Lists

# %%
nest
# Out:
# [[1, 2], [3, 4]]

# %%
nest[0][1] # Accessing first array, then second index value
# Out:
# 2

# %%
nest[1][1] # Accessing second array, then second index value
# Out:
# 4

# %%
nest[0][0] # Accessing first array, then first index value
# Out:
# 1

# %%
nest[1][0] #Accessing second array, then first index value
# Out:
# 3

# %%
nest2 = [1,2,3,[4,5,['target']]]

# %%
nest2
# Out:
# [1, 2, 3, [4, 5, ['target']]]

# %%
nest2[3]  # Get the 4th element (0,1,2,3)
# Out:
# [4, 5, ['target']]

# %%
nest2[3][2] # Get the 3rd element in the list, which is 'target', at the 2nd index
# Out:
# ['target']

# %%
nest2[3][2][0] # Get the first index value in the list, which is the string 'target', at the 0 index
# Out:
# 'target'

# %%
print(nest2[3][2][0])
# Out:
# target
