# %% [markdown]
# <h3>MAP/Filter Functions</h3>

# %%
# Function Review:

def times2(var):
    return var *2

# %%
times2(5)
# Out:
# 10

# %%
# MAP() - 'Automatically' applies a function against a list, and provides output

# %%
seq = [1,2,3,4,5]

# %%
map(times2,seq) # Pass in the called function (times2) and the desired list (seq)

# This shows where the map is in memory
# Have to wrap map into a list in order to execute and get output

# %%
list(map(times2,seq)) # Map wrapped in a list
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# <h3>Lambda-Lambda-Lambda</h3>

# %%
# Lambda Express - Reduce having to write out a full function

# %%
# Take this function, for example, and write it all on one line:
 def times2(var): return var *2

# %%
# Remove key words *def* and *return*, because these are well known words for creating functions:

# %%
 times2(var):var *2

# %%
# Replace the function name (times2) with a lambda expression, and remove the () around the passed parameter (var):

# %%
lambda var:var*2
# Out:
# <function __main__.<lambda>>

# %%
# Wrap the lambda expression in a map and list --> list(map())

# %%
# lambda <what you want to pass in the lambda 'function'> (num) : <the expected ouput or code to perform>, and some list (seq)

# %%
# This example takes a number from the seq list, and multiplies them by 3

# %%
list(map(lambda num: num*3,seq))
# Out:
# [3, 6, 9, 12, 15]

# %% [markdown]
# <h3>Filter</h3>

# %%
# Filter() -  out elements from a sequence, and returns results based on BOOLEAN evaluation

# %%
filter(lambda num: num%2 == 0, seq)

# %%
list(filter(lambda num:num%2 == 0, seq)) # This returns the even numbers from the seq list
# Out:
# [2, 4]

# %% [markdown]
# <h3>Methods, Man -lol</h3>

# %%
s = 'hello my is Sam'

# %%
# Hit TAB after the . to show all assocated methods that can be used

# %%
s.lower() # String Methods
# Out:
# 'hello my is sam'

# %%
s.upper()
# Out:
# 'HELLO MY IS SAM'

# %%
s.split()
# Out:
# ['hello', 'my', 'is', 'Sam']

# %%
tweet = 'Go Sports! #Sports' # Example of Tweet string to use for understanding split()

# %%
tweet.split('#') # Split on the '#'
# Out:
# ['Go Sports! ', 'Sports']

# %%
len(tweet.split('#')) # Get the length of the tweet split
# Out:
# 2

# %%
tweet.split('#')[0]
# Out:
# 'Go Sports! '

# %%
tweet.split('#')[1]
# Out:
# 'Sports'

# %%
d = {'k1': 1, 'k2': 2} # Dictionary methods

# %%
d.keys()
# Out:
# dict_keys(['k2', 'k1'])

# %%
d.items()
# Out:
# dict_items([('k2', 2), ('k1', 1)])

# %%
d.values()
# Out:
# dict_values([2, 1])

# %%
lst1 = [1,2,3] # List Methods

# %%
lst1.pop() # Pop the last item out of the list
# Out:
# 3

# %%
lst1
# Out:
# [1, 2]

# %%
lst1 = [1,2,3,4,5]

# %%
item = lst1.pop()  # Pop last item off of list, and assign to var item

# %%
lst1
# Out:
# [1, 2, 3, 4]

# %%
item
# Out:
# 5

# %%
first = lst1.pop(0) # Pop the first index item out of the list, and assign it to var first

# %%
first
# Out:
# 1

# %%
lst1
# Out:
# [2, 3, 4]

# %%
lst1.append('new')  # Append new to the end of the list

# %%
lst1
# Out:
# [2, 3, 4, 'new']

# %% [markdown]
# <h3>IN</h3>

# %%
'x' in 'fox'
# Out:
# True

# %%
'x' in 'car'
# Out:
# False

# %%
'why' in ['box','why','zebra']
# Out:
# True

# %%
'4' in [1,2,3]
# Out:
# False

# %%
apple = {'k1': 'butter', 'k2': 'ketchup'}

# %%
'butter' in apple.values()
# Out:
# True

# %% [markdown]
# <h3>Tuple Unpacking</h3>

# %%
x = [(1,2),(3,4),(5,6)]

# %%
for item in x:
    print(item)
# Out:
# (1, 2)
# (3, 4)
# (5, 6)

# %%
for (a,b) in x:
    print(a)
# Out:
# 1
# 3
# 5

# %%
for (a,b) in x:
    print(b)
# Out:
# 2
# 4
# 6

# %%
[a for (a,b) in x]  # Unpacking Tuple using list comprehension to get the odd numbers
# Out:
# [1, 3, 5]

# %%
[b for (a,b) in x] # Unpacking Tuple using list comprehension to get the even numbers
# Out:
# [2, 4, 6]

# %%
h = [b for (a,b) in x] # Unpack Tuple using list comprehension and assign to h

# %%
h
# Out:
# [2, 4, 6]

# %%
h[1] # Slice to get index value for 1
# Out:
# 4
